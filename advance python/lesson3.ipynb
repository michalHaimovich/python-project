# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 12.6/12.6 MB 4.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python311\\Scripts\\f2py.exe' -> 'C:\\Python311\\Scripts\\f2py.exe.deleteme'
#
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
rand_arr = np.random.randint(1,50,size = (1,10))

# %%
rand_arr
# Out:
# array([[10, 31, 24, 45, 17, 47, 29, 36, 44, 34]], dtype=int32)

# %%
rand_arr.size
# Out:
# 10

# %%
np.shape(rand_arr)
# Out:
# (1, 10)

# %%
rand_arr.dtype
# Out:
# dtype('int32')

# %% [markdown]
# 2

# %%
two_d_arr = np.random.randint(10,100,size = (2,5))

# %%
two_d_arr
# Out:
# array([[92, 19, 36, 77, 84],
#        [44, 41, 20, 90, 20]], dtype=int32)

# %% [markdown]
# ## home work

# %%
arr = np.random.randint(1,50 ,size =(1,10))

# %%
np.mean(arr)
# Out:
# np.float64(26.6)

# %%
arr
# Out:
# array([[21, 38, 34, 44, 45,  1, 18, 21, 33, 11]], dtype=int32)

# %% [markdown]
# ## 2

# %%
mat1 = np.array([[1,2,3],[4,5,6],[6,7,8]])
mat2 = np.array([[11,22,31],[54,75,69],[46,37,28]])
res = mat1 + mat2
np.mean(res)
# Out:
# np.float64(46.111111111111114)

# %% [markdown]
# ## 3

# %%
arr3 = np.random.randint(1,100 ,size =(1,20))

# %%
arr3
# Out:
# array([[ 3, 67, 68, 53, 90,  8, 82,  7, 84, 30, 99, 86,  6, 15, 31, 52,
#         39, 17, 70, 87]], dtype=int32)

# %%
bigger = arr3[arr3 > 50]

# %%
bigger
# Out:
# array([67, 68, 53, 90, 82, 84, 99, 86, 52, 70, 87], dtype=int32)

# %% [markdown]
# ## 4

# %%
arr4 = np.random.randint(1,50 ,size =(1,10))

# %%
res4 = arr4.reshape(5,2)

# %%
arr4
# Out:
# array([[23, 39, 23, 19,  7, 48, 12,  9, 14, 10]], dtype=int32)

# %%
res4
# Out:
# array([[23, 39],
#        [23, 19],
#        [ 7, 48],
#        [12,  9],
#        [14, 10]], dtype=int32)

# %%
res4[3][1]
# Out:
# np.int32(9)
